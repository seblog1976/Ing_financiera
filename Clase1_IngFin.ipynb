# %% [markdown]
# ## Clase 1
# ##### Ingeniería Financiera

# %%
equity=[5.5,2.35,3.4,4,5.67]

# %%
equity
# Out:
# [5.5, 2.35, 3.4, 4, 5.67]

# %%
equity_volum=list()

# %%
equity_volum
# Out:
# []

# %%
for numero in equity:
   equity_volum.append(numero)

# %%
equity_volum
# Out:
# [5.5, 2.35, 3.4, 4, 5.67]

# %%
import random

# %%
dado=random.randint(1,100)

# %%
dado
# Out:
# 7

# %%
for numero in range(1000):
    equity_volum.append(random.randint(1,100))

# %%
# equity_volum

# %%
x=0
while x<=100:
    dado=random.randint(1,100)
    print(dado)
    x+=1
# Out:
# 62
# 6
# 72
# 50
# 61
# 98
# 33
# 100
# 53
# 33
# 8
# 52
# 53
# 68
# 12
# 65
# 91
# 34
# 21
# 14
# 20
# 47
# 96
# 79
# 35
# 33
# 85
# 40
# 35
# 82
# 38
# 91
# 55
# 34
# 97
# 77
# 55
# 47
# 28
# 53
# 30
# 69
# 63
# 76
# 83
# 79
# 92
# 43
# 19
# 20
# 8
# 20
# 51
# 77
# 49
# 68
# 31
# 38
# 31
# 15
# 22
# 87
# 68
# 79
# 64
# 54
# 43
# 25
# 93
# 10
# 40
# 96
# 4
# 13
# 71
# 5
# 95
# 5
# 17
# 31
# 40
# 76
# 71
# 77
# 20
# 42
# 62
# 91
# 5
# 6
# 5
# 77
# 76
# 72
# 81
# 91
# 33
# 60
# 22
# 75
# 7

# %%
def cf_series(face,cupon,maturity):
    cf=[]
    for c in range(maturity):
        cf.append(face*cupon)
    cf[-1]=cf[-1]+face
    return cf

# %%
bono=cf_series(100,0.03,5)

# %%
bono
# Out:
# [3.0, 3.0, 3.0, 3.0, 103.0]

# %%
bono_2=cf_series(100,0.2,7)

# %%
bono_2
# Out:
# [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 120.0]

# %%
x=0
nominal=100
mat=5
while x<=100:
    tasa=random.randint(1,100)/100
    x+=1
    print(cf_series(nominal,tasa,mat))
# Out:
# [72.0, 72.0, 72.0, 72.0, 172.0]
# [90.0, 90.0, 90.0, 90.0, 190.0]
# [53.0, 53.0, 53.0, 53.0, 153.0]
# [84.0, 84.0, 84.0, 84.0, 184.0]
# [94.0, 94.0, 94.0, 94.0, 194.0]
# [9.0, 9.0, 9.0, 9.0, 109.0]
# [72.0, 72.0, 72.0, 72.0, 172.0]
# [41.0, 41.0, 41.0, 41.0, 141.0]
# [9.0, 9.0, 9.0, 9.0, 109.0]
# [48.0, 48.0, 48.0, 48.0, 148.0]
# [2.0, 2.0, 2.0, 2.0, 102.0]
# [47.0, 47.0, 47.0, 47.0, 147.0]
# [22.0, 22.0, 22.0, 22.0, 122.0]
# [34.0, 34.0, 34.0, 34.0, 134.0]
# [77.0, 77.0, 77.0, 77.0, 177.0]
# [62.0, 62.0, 62.0, 62.0, 162.0]
# [15.0, 15.0, 15.0, 15.0, 115.0]
# [16.0, 16.0, 16.0, 16.0, 116.0]
# [71.0, 71.0, 71.0, 71.0, 171.0]
# [30.0, 30.0, 30.0, 30.0, 130.0]
# [41.0, 41.0, 41.0, 41.0, 141.0]
# [24.0, 24.0, 24.0, 24.0, 124.0]
# [16.0, 16.0, 16.0, 16.0, 116.0]
# [92.0, 92.0, 92.0, 92.0, 192.0]
# [12.0, 12.0, 12.0, 12.0, 112.0]
# [74.0, 74.0, 74.0, 74.0, 174.0]
# [16.0, 16.0, 16.0, 16.0, 116.0]
# [69.0, 69.0, 69.0, 69.0, 169.0]
# [53.0, 53.0, 53.0, 53.0, 153.0]
# ...
